# %% [markdown]
# <a href="https://colab.research.google.com/github/alihussainia/OpenDevLibrary/blob/master/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # OpenDevLibrary Project Cloning

# %%
cd /content
# Out:
# /content

# %%
# !git clone "https://github.com/alihussainia/OpenDevLibrary.git"
# Out:
# Cloning into 'OpenDevLibrary'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 218 (delta 7), reused 0 (delta 0), pack-reused 203
# Receiving objects: 100% (218/218), 71.70 MiB | 31.98 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %% [markdown]
# # OpenVINO Installation

# %%
cd OpenDevLibrary/
# Out:
# /content/OpenDevLibrary

# %%
# !python openvino_initialization_script.py

# %%
install_dir = '/opt/intel/openvino/'
model_optimizer = '/opt/intel/openvino/deployment_tools/model_optimizer/'
deployment_tools = '/opt/intel/openvino/deployment_tools/'
model_zoo = '/opt/intel/openvino/deployment_tools/open_model_zoo/'

# %% [markdown]
# # Downloading Model

# %%
# !python $model_zoo'tools/downloader/'downloader.py --name vehicle-attributes-recognition-barrier-0039 --precisions FP32-INT8 -o /content/OpenDevLibrary/demo_files/models
# Out:
# ################|| Downloading models ||################
#
# ========== Downloading /content/OpenDevLibrary/demo_files/models/intel/vehicle-attributes-recognition-barrier-0039/FP32-INT8/vehicle-attributes-recognition-barrier-0039.xml
# ... 100%, 85 KB, 5758 KB/s, 0 seconds passed
#
# ========== Downloading /content/OpenDevLibrary/demo_files/models/intel/vehicle-attributes-recognition-barrier-0039/FP32-INT8/vehicle-attributes-recognition-barrier-0039.bin
# ... 100%, 2453 KB, 71134 KB/s, 0 seconds passed
#
# ################|| Post-processing ||################

# %% [markdown]
# # Running Inference

# %%
cd /content/OpenDevLibrary/demo_files/
# Out:
# /content/OpenDevLibrary/demo_files

# %%
# !source /opt/intel/openvino/bin/setupvars.sh && python app.py -i "images/blue-car.jpg" -t "CAR_META" -m "/content/OpenDevLibrary/demo_files/models/intel/vehicle-attributes-recognition-barrier-0039/FP32-INT8/vehicle-attributes-recognition-barrier-0039.xml"
# Out:
# [setupvars.sh] OpenVINO environment initialized
# Success

# %% [markdown]
# # Output

# %%
cd /content/OpenDevLibrary/demo_files/outputs/
# Out:
# /content/OpenDevLibrary/demo_files/outputs

# %%
#!curl -o car.png
from google.colab.patches import cv2_imshow
import cv2


img = cv2.imread("CAR_META-output.png", cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x562 at 0x7FEEB21A6A58>
